# %%
import os
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

df = pd.read_csv(r"D:\01.Educación\03.MMA\03.Fall 2024\02.Decision analytics (MGSC 662)\05.Project\02.Project solar panels distribution\finaldataset.csv")
df['PercentagePark'] = df['PercentagePark'].fillna(0)
df['GridAll'] = df['GridAll'].fillna(0)

# %% [markdown]
# **Changes**
#
# - Budget to 4 billion
# - Districts not connect to grid produce 100% of its demand
# - Districts cannot produce over 200% of its demand
# - Only grid connected districts can import

# %% [markdown]
# # **Optimization Model for Solar Panel Installation**
#
# ## **Decision Variables**
# - $X_i$: Installed capacity in district $i$ (MW).
# - $Z_i$: Total number of panels installed in district $i$ (integer).
# - $T_{k,i}$: Number of panels transported from supplier $k$ to district $i$ (integer).
# - $y_i$: Binary variable indicating whether panels are installed in district $i$ ($1$ if installed, $0$ otherwise).
# - $A_{j,i}$: Energy transferred from district $j$ to district $i$ (MW).
# - $E_i$: Total energy produced in district $i$ (MW).
# - $I_i$: Imported electricity in district $i$ (MW).
# - $s_i$: Surplus energy in district $i$ (MW).
# - $E_{\text{exp},i}$: Exportable energy from district $i$ (MW).
# - $\delta_i$: Binary variable indicating if district $i$ exports energy.
#
# ---
#
# ## **Parameters**
# - $EP$: Energy production per panel (MW).
# - $S_i$: Solar potential for district $i$ (MW/MWp/month).
# - $ED_i$: Energy demand in district $i$ (MW/month).
# - $D_{k,i}$: Distance from supplier $k$ to district $i$ (km).
# - $D_{j,i}$: Distance from district $j$ to district $i$ (km).
# - $C_{\text{install}}$: Installation cost per MW ($).
# - $C_T$: Transportation cost per panel per km ($).
# - $B$: Total budget ($).
# - $M$: Large constant for binary constraints.
# - $\gamma$: Transmission loss factor per km.
# - $C_{\text{max}}$: Maximum transmission capacity (MW/month).
# - $\alpha_i$: Demand satisfaction ratio for district $i$:
# $$
# \alpha_i =
# \begin{cases}
# 0.05, & \text{if district $i$ is grid-connected} \\
# 1, & \text{otherwise}
# \end{cases}
# $$
# - $GridAll_i$: Indicator if district $i$ is grid-connected ($1$ if connected, $0$ otherwise).
#
# ---
#
# ## **Objective Function**
#
# The objective is to minimize the total cost of solar panel installation and transportation:
#
# $$
# \min Z = \sum_{i=1}^{n} X_i \cdot C_{\text{install}} + \sum_{k=1}^{m} \sum_{i=1}^{n} T_{k,i} \cdot C_T \cdot D_{k,i}
# $$
#
# ### **Explanation of Variables and Parameters:**
# - $Z$: Total cost of installation and transportation.
# - $X_i$: Installed capacity in district $i$ (MW).
# - $C_{\text{install}}$: Installation cost per MW ($).
# - $T_{k,i}$: Number of panels transported from supplier $k$ to district $i$.
# - $C_T$: Transportation cost per panel per kilometer ($).
# - $D_{k,i}$: Distance from supplier $k$ to district $i$ (km).
# - $n$: Total number of districts.
# - $m$: Total number of suppliers.

# %% [markdown]
# ---
#
# ## **Constraints**
#
# ### **1. Panels Balance**
# The total number of panels transported to each district equals the number of panels installed:
#
# $$
# \sum_{k=1}^{m} T_{k,i} = Z_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $T_{k,i}$: Panels transported from supplier $k$ to district $i$.
# - $Z_i$: Total number of panels installed in district $i$.
#
# ---
#
# ### **2. Installed Capacity**
# Installed capacity is proportional to the number of panels installed:
#
# $$
# X_i = Z_i \cdot EP, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $X_i$: Installed capacity in district $i$ (MW).
# - $Z_i$: Total number of panels installed in district $i$.
# - $EP$: Energy production per panel (MW).
#
# ---
#
# ### **3. Demand Satisfaction**
# Local production plus imported electricity must meet the adjusted demand:
#
# $$
# X_i \cdot S_i + I_i \geq ED_i \cdot \alpha_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $S_i$: Solar efficiency factor for district $i$.
# - $I_i$: Imported electricity in district $i$ (MW).
# - $ED_i$: Energy demand in district $i$ (MW).
# - $\alpha_i$: Demand satisfaction ratio for district $i$.
#
# ---
#
# ### **4. Surplus and Exportable Energy**
# Surplus energy in a district is defined as:
#
# $$
# s_i = X_i \cdot S_i - ED_i \cdot \alpha_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# Exportable energy is:
#
# $$
# E_{\text{exp},i} = s_i \cdot \delta_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $s_i$: Surplus energy in district $i$ (MW).
# - $E_{\text{exp},i}$: Exportable energy from district $i$ (MW).
# - $\delta_i$: Binary variable indicating if district $i$ exports energy.
#
# ---
#
# ### **5. Imported Electricity**
# Imported electricity considers transmission losses:
#
# $$
# I_i = \sum_{\substack{j=1 \\ j \neq i}}^{n} A_{j,i} \cdot e^{-\gamma D_{j,i}}, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $A_{j,i}$: Energy transferred from district $j$ to district $i$ (MW).
# - $\gamma$: Transmission loss factor per km.
# - $D_{j,i}$: Distance from district $j$ to district $i$ (km).
#
# ---
#
# ### **6. Binary Installation Constraint**
# Installed capacity is limited by the installation decision:
#
# $$
# X_i \leq M \cdot y_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# - $M$: Large constant for binary constraints.
# - $y_i$: Binary variable indicating whether panels are installed in district $i$.
#
# ---
#
# ### **7. Energy Production for Non-Grid Districts**
# For districts without grid connection ($GridAll_i = 0$):
#
# $$
# E_i \geq ED_i, \quad \forall i \text{ where } GridAll_i = 0
# $$
#
# - $E_i$: Total energy produced in district $i$ (MW).
#
# ---
#
# ### **8. Maximum Production Limit**
# Production in each district cannot exceed twice its demand:
#
# $$
# E_i \leq 2 \cdot ED_i, \quad \forall i \in \{1, \dots, n\}
# $$
#
# ---
#
# ### **9. Export Limit by Surplus**
# Energy exported cannot exceed exportable energy:
#
# $$
# \sum_{\substack{i=1 \\ i \neq j}}^{n} A_{j,i} \leq E_{\text{exp},j}, \quad \forall j \in \{1, \dots, n\}
# $$
#
# ---
#
# ### **10. Transmission Capacity Limit**
# Exports are limited by the transmission capacity:
#
# $$
# \sum_{\substack{i=1 \\ i \neq j}}^{n} A_{j,i} \leq C_{\text{max}} \cdot \delta_j, \quad \forall j \in \{1, \dots, n\}
# $$
#
# - $C_{\text{max}}$: Maximum transmission capacity (MW).
#
# ---
#
# ### **11. No Self-Transfer**
# Districts cannot transfer energy to themselves:
#
# $$
# A_{j,j} = 0, \quad \forall j \in \{1, \dots, n\}
# $$
#
# ---
#
# ### **12. Energy Balance**
# The total imported energy equals total transmitted energy after losses:
#
# $$
# \sum_{i=1}^{n} I_i = \sum_{j=1}^{n} \sum_{\substack{i=1 \\ i \neq j}}^{n} A_{j,i} \cdot e^{-\gamma D_{j,i}}
# $$
#
# ---
#
# ### **13. Budget Constraint**
# Total costs must not exceed the budget:
#
# $$
# \sum_{i=1}^{n} X_i \cdot C_{\text{install}} + \sum_{k=1}^{m} \sum_{i=1}^{n} T_{k,i} \cdot C_T \cdot D_{k,i} \leq B
# $$
#
# - $B$: Total budget ($).

# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np

district_ids = df['ID'].tolist()
district_names = df['Name'].tolist()
num_districts = len(df)
supplier_indices = df[df['Suppliers'] == 1].index.tolist()
num_suppliers = len(supplier_indices)

energy_consumption_per_person = (96.3 / 4.5)  # kWh/month divided by average people per household
C_install = 1.1e6  # Installation cost per MW ($)
C_T = 0.1  # Transportation cost per panel per km ($)
B = 4e9  # Budget ($) - updated to 3 billion
transmission_loss_per_km = 0.0377 / 1000  # Loss per km (fraction)
max_transmission_capacity = 500  # MW/month
M = 1e6  # Big M for binary constraints
EP = 0.3 / 1e3  # Panel capacity (MWp)

ED = df['2021_Total_Population'] * energy_consumption_per_person / 1e6  # MW/month
S = df['MEANSOLAR'] * 30 / 1e3  # Convert to MW per MWp per month
P = df['PercentagePark'].values / 100

X_coords = df['X'].values
Y_coords = df['Y'].values
D = np.zeros((num_districts, num_districts))

def haversine(lon1, lat1, lon2, lat2):
    # Calculate distance between two points on Earth
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    km = 6371 * c  # Radius of Earth in km
    return km

for i in range(num_districts):
    for j in range(num_districts):
        if i != j:
            D[i, j] = haversine(X_coords[i], Y_coords[j], X_coords[j], Y_coords[i])

# Initialize model
model = gp.Model("Solar_Panels_Optimization")
model.Params.LogToConsole = 0

# Decision Variables
X = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="InstalledCapacity")
Z = model.addVars(num_districts, vtype=GRB.INTEGER, lb=0, name="TotalPanels")
T = model.addVars(num_suppliers, num_districts, vtype=GRB.INTEGER, lb=0, name="TransportedPanels")
y = model.addVars(num_districts, vtype=GRB.BINARY, name="InstallDecision")
A = model.addVars(num_districts, num_districts, vtype=GRB.CONTINUOUS, lb=0, name="TransferredEnergy")
exportable_energy = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="ExportableEnergy")
surplus = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=-GRB.INFINITY, name="Surplus")
delta = model.addVars(num_districts, vtype=GRB.BINARY, name="ExportDecision")
imported_electricity = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="ImportedElectricity")
E = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="EnergyProduced")

# Objective: Minimize installation and transportation costs
model.setObjective(
    gp.quicksum(X[i] * C_install for i in range(num_districts)) +
    gp.quicksum(T[k, i] * C_T * D[supplier_indices[k], i] for k in range(num_suppliers) for i in range(num_districts)),
    GRB.MINIMIZE
)

# Define demand satisfaction ratio based on GridConnections
demand_satisfaction_ratio = [
    0.05 if df.loc[i, 'GridAll'] > 0 else 1
    for i in range(num_districts)
]

# Constraints
for i in range(num_districts):
    # Panels balance
    model.addConstr(gp.quicksum(T[k, i] for k in range(num_suppliers)) == Z[i], f"PanelsBalance_District_{i}")
    
    # Installed capacity
    model.addConstr(X[i] == Z[i] * EP, f"InstalledCapacity_District_{i}")

    # Demand satisfaction with adjusted ratio
    local_production = X[i] * S[i]
    model.addConstr(
        local_production + imported_electricity[i] >= ED[i] * demand_satisfaction_ratio[i],
        f"DemandSatisfaction_District_{i}"
    )
    
    # Surplus and exportable energy
    model.addConstr(surplus[i] == local_production - ED[i] * demand_satisfaction_ratio[i], f"Surplus_District_{i}")
    model.addConstr(exportable_energy[i] == surplus[i] * delta[i], f"ExportableEnergy_District_{i}")
    
    # Import electricity
    model.addConstr(
        imported_electricity[i] == gp.quicksum(A[j, i] * np.exp(-transmission_loss_per_km * D[j, i]) for j in range(num_districts) if j != i),
        f"ImportedElectricity_District_{i}"
    )
    
    # Binary installation constraints
    model.addConstr(X[i] <= M * y[i], f"BinaryInstallationConstraint_District_{i}")
    
    # Grid constraint for delta[i]
    if df.loc[i, 'GridAll'] == 0:
        model.addConstr(delta[i] == 0, f"GridConstraint_District_{i}")
    
    # Surplus and Export Decision
    model.addConstr(
        surplus[i] >= 0.0001 - M * (1 - delta[i]),
        f"PositiveSurplusForExport_District_{i}"
    )

    # Energy production constraint for districts without grid (100% of demand)
    if df.loc[i, 'GridAll'] == 0:
        model.addConstr(E[i] >= ED[i], f"MinProductionNoGrid_District_{i}")
    
    # Link energy produced (E[i]) to local production
    model.addConstr(E[i] == X[i] * S[i], f"EnergyProduced_District_{i}")
    
    # Maximum production limit (200% of demand)
    model.addConstr(E[i] <= 2 * ED[i], f"MaxProductionLimit_District_{i}")

for j in range(num_districts):
    # Export Limit by Surplus
    model.addConstr(
        gp.quicksum(A[j, i] for i in range(num_districts) if i != j) <= exportable_energy[j],
        f"ExportLimit_District_{j}"
    )
    # Transmission Capacity Limit
    model.addConstr(
        gp.quicksum(A[j, i] for i in range(num_districts) if i != j) <= max_transmission_capacity * delta[j],
        f"TransmissionCapacity_District_{j}"
    )
    # No Self-Transfer
    model.addConstr(A[j, j] == 0, f"NoSelfTransfer_District_{j}")

# Energy balance
model.addConstr(
    gp.quicksum(imported_electricity[i] for i in range(num_districts)) == 
    gp.quicksum(A[j, i] * np.exp(-transmission_loss_per_km * D[j, i]) for j in range(num_districts) for i in range(num_districts) if i != j),
    "EnergyBalance"
)

# Budget constraint
total_cost = gp.quicksum(X[i] * C_install for i in range(num_districts)) + \
             gp.quicksum(T[k, i] * C_T * D[supplier_indices[k], i] for k in range(num_suppliers) for i in range(num_districts))
model.addConstr(total_cost <= B, "BudgetConstraint")

# Optimize and display results
model.optimize()

if model.status == GRB.OPTIMAL:
    # Total summary
    total_panels_installed = sum(Z[i].x for i in range(num_districts))
    total_installed_capacity = sum(X[i].x for i in range(num_districts))
    total_cost = model.objVal

    print("Optimization Results")
    print("====================")
    print(f"Total Cost: ${total_cost:,.2f}")
    print(f"Total Number of Panels Installed: {total_panels_installed:,.0f}")
    print(f"Total Installed Capacity: {total_installed_capacity:.2f} MW")
    print("\nDetails by District")
    print("====================")
    for i in range(num_districts):
        panels_installed = Z[i].x
        installed_capacity = X[i].x
        local_prod = installed_capacity * S[i]
        imp_elec = imported_electricity[i].x
        demand = ED[i]

        print(f"District {district_names[i]}:")
        print(f"  Panels Installed: {panels_installed:,.0f}")
        print(f"  Installed Capacity: {installed_capacity:.2f} MW")
        print(f"  Local Production: {local_prod:.2f} MW")
        print(f"  Capacity Imported: {imp_elec:.2f} MW")
        print(f"  Demand: {demand:.2f} MW")
        print("-" * 30)
else:
    print("No feasible solution found.")
# Out:
# Optimization Results
# ====================
# Total Cost: $3,300,218,535.28
# Total Number of Panels Installed: 9,779,652
# Total Installed Capacity: 2933.90 MW
#
# Details by District
# ====================
# District Abim:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.20 MW
#   Demand: 4.01 MW
# ------------------------------
# District Adjumani:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.26 MW
# ------------------------------
# District Agago:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.29 MW
#   Demand: 5.76 MW
# ------------------------------
# District Amuru:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.25 MW
#   Demand: 5.10 MW
# ------------------------------
# District Arua:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.18 MW
#   Demand: 3.69 MW
# ------------------------------
# District Gulu:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.14 MW
#   Demand: 2.79 MW
# ------------------------------
# District Koboko:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.32 MW
#   Demand: 6.31 MW
# ------------------------------
# District Kole:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.34 MW
#   Demand: 6.77 MW
# ------------------------------
# District Kotido:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.24 MW
#   Demand: 4.82 MW
# ------------------------------
# District Lira:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.28 MW
#   Demand: 5.56 MW
# ------------------------------
# District Maracha:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.24 MW
#   Demand: 4.81 MW
# ------------------------------
# District Moroto:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.14 MW
#   Demand: 2.77 MW
# ------------------------------
# District Moyo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.13 MW
#   Demand: 2.55 MW
# ------------------------------
# District Napak:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.18 MW
#   Demand: 3.64 MW
# ------------------------------
# District Nebbi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.34 MW
#   Demand: 6.72 MW
# ------------------------------
# District Nwoya:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.34 MW
#   Demand: 6.89 MW
# ------------------------------
# District Omoro:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.24 MW
#   Demand: 4.75 MW
# ------------------------------
# District Oyam:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.54 MW
#   Demand: 10.78 MW
# ------------------------------
# District Pader:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.23 MW
#   Demand: 4.53 MW
# ------------------------------
# District Pakwach:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.24 MW
#   Demand: 4.80 MW
# ------------------------------
# District Obongi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.06 MW
#   Demand: 1.15 MW
# ------------------------------
# District Madi Okollo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.19 MW
#   Demand: 3.88 MW
# ------------------------------
# District Arua City:
#   Panels Installed: 28,173
#   Installed Capacity: 8.45 MW
#   Local Production: 1.17 MW
#   Capacity Imported: 0.00 MW
#   Demand: 8.54 MW
# ------------------------------
# District Gulu City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.25 MW
#   Demand: 4.95 MW
# ------------------------------
# District Lira City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.29 MW
#   Demand: 5.75 MW
# ------------------------------
# District Amuria:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.27 MW
#   Demand: 5.45 MW
# ------------------------------
# District Bugiri:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.59 MW
#   Demand: 11.76 MW
# ------------------------------
# District Bugweri:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.23 MW
#   Demand: 4.51 MW
# ------------------------------
# District Busia:
#   Panels Installed: 430,332
#   Installed Capacity: 129.10 MW
#   Local Production: 18.27 MW
#   Capacity Imported: 0.00 MW
#   Demand: 9.14 MW
# ------------------------------
# District Iganga:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.48 MW
#   Demand: 9.58 MW
# ------------------------------
# District Jinja:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.28 MW
#   Demand: 5.59 MW
# ------------------------------
# District Katakwi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.23 MW
#   Demand: 4.60 MW
# ------------------------------
# District Luuka:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.31 MW
#   Demand: 6.18 MW
# ------------------------------
# District Mayuge:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.67 MW
#   Demand: 13.49 MW
# ------------------------------
# District Soroti:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.36 MW
#   Demand: 7.10 MW
# ------------------------------
# District Tororo:
#   Panels Installed: 308,865
#   Installed Capacity: 92.66 MW
#   Local Production: 12.95 MW
#   Capacity Imported: 0.00 MW
#   Demand: 14.03 MW
# ------------------------------
# District Jinja City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.31 MW
#   Demand: 6.16 MW
# ------------------------------
# District Buikwe:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.55 MW
#   Demand: 10.96 MW
# ------------------------------
# District Bukomansimbi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.17 MW
#   Demand: 3.47 MW
# ------------------------------
# District Butambala:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.12 MW
#   Demand: 2.43 MW
# ------------------------------
# District Kalangala:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.08 MW
#   Demand: 1.63 MW
# ------------------------------
# District Kalungu:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.21 MW
#   Demand: 4.15 MW
# ------------------------------
# District Kampala Capital City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 1.94 MW
#   Demand: 38.74 MW
# ------------------------------
# District Kayunga:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.47 MW
#   Demand: 9.37 MW
# ------------------------------
# District Kyankwanzi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.36 MW
#   Demand: 7.10 MW
# ------------------------------
# District Kyotera:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.30 MW
#   Demand: 5.95 MW
# ------------------------------
# District Luwero:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.61 MW
#   Demand: 12.24 MW
# ------------------------------
# District Lwengo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.33 MW
#   Demand: 6.52 MW
# ------------------------------
# District Lyantonde:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.13 MW
#   Demand: 2.62 MW
# ------------------------------
# District Masaka:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.14 MW
#   Demand: 2.80 MW
# ------------------------------
# District Mpigi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.33 MW
#   Demand: 6.70 MW
# ------------------------------
# District Mukono:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.83 MW
#   Demand: 16.61 MW
# ------------------------------
# District Nakaseke:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.28 MW
#   Demand: 5.59 MW
# ------------------------------
# District Nakasongola:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.12 MW
# ------------------------------
# District Rakai:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.37 MW
#   Demand: 7.43 MW
# ------------------------------
# District Ssembabule:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.35 MW
#   Demand: 7.00 MW
# ------------------------------
# District Wakiso:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 3.86 MW
#   Demand: 77.18 MW
# ------------------------------
# District Masaka City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.20 MW
# ------------------------------
# District Bundibugyo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.31 MW
#   Demand: 6.25 MW
# ------------------------------
# District Bushenyi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.28 MW
#   Demand: 5.57 MW
# ------------------------------
# District Ibanda:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.32 MW
#   Demand: 6.38 MW
# ------------------------------
# District Isingiro:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.72 MW
#   Demand: 14.43 MW
# ------------------------------
# District Kabale:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.28 MW
#   Demand: 5.63 MW
# ------------------------------
# District Kabarole:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.16 MW
# ------------------------------
# District Kagadi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.52 MW
#   Demand: 10.41 MW
# ------------------------------
# District Kakumiro:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.66 MW
#   Demand: 13.20 MW
# ------------------------------
# District Kasese:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.93 MW
#   Demand: 18.51 MW
# ------------------------------
# District Kibaale:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.15 MW
# ------------------------------
# District Kikuube:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.45 MW
#   Demand: 9.09 MW
# ------------------------------
# District Kiruhura:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.23 MW
#   Demand: 4.50 MW
# ------------------------------
# District Kiryandongo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.37 MW
#   Demand: 7.44 MW
# ------------------------------
# District Kyenjojo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.64 MW
#   Demand: 12.82 MW
# ------------------------------
# District Masindi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.40 MW
#   Demand: 8.05 MW
# ------------------------------
# District Mbarara:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.20 MW
#   Demand: 3.93 MW
# ------------------------------
# District Ntungamo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.62 MW
#   Demand: 12.48 MW
# ------------------------------
# District Rubirizi:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.17 MW
#   Demand: 3.32 MW
# ------------------------------
# District Rukiga:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.12 MW
#   Demand: 2.35 MW
# ------------------------------
# District Sheema:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.25 MW
#   Demand: 4.96 MW
# ------------------------------
# District Kazo:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.27 MW
# ------------------------------
# District Rwampara:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.17 MW
#   Demand: 3.36 MW
# ------------------------------
# District Fort Portal City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.13 MW
#   Demand: 2.68 MW
# ------------------------------
# District Hoima City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.15 MW
#   Demand: 2.97 MW
# ------------------------------
# District Mbarara City:
#   Panels Installed: -0
#   Installed Capacity: 0.00 MW
#   Local Production: 0.00 MW
#   Capacity Imported: 0.26 MW
#   Demand: 5.15 MW
# ------------------------------
# District Alebtong:
#   Panels Installed: 148,078
#   Installed Capacity: 44.42 MW
#   Local Production: 6.28 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.28 MW
# ------------------------------
# District Amolatar:
#   Panels Installed: 92,867
#   Installed Capacity: 27.86 MW
#   Local Production: 3.99 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.99 MW
# ------------------------------
# District Amudat:
#   Panels Installed: 77,782
#   Installed Capacity: 23.33 MW
#   Local Production: 3.33 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.33 MW
# ------------------------------
# District Apac:
#   Panels Installed: 132,232
#   Installed Capacity: 39.67 MW
#   Local Production: 5.47 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.47 MW
# ------------------------------
# District Dokolo:
#   Panels Installed: 120,507
#   Installed Capacity: 36.15 MW
#   Local Production: 5.11 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.11 MW
# ------------------------------
# District Kaabong:
#   Panels Installed: 70,227
#   Installed Capacity: 21.07 MW
#   Local Production: 2.95 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.95 MW
# ------------------------------
# District Kitgum:
#   Panels Installed: 125,785
#   Installed Capacity: 37.74 MW
#   Local Production: 5.11 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.11 MW
# ------------------------------
# District Kwania:
#   Panels Installed: 121,840
#   Installed Capacity: 36.55 MW
#   Local Production: 5.15 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.14 MW
# ------------------------------
# District Lamwo:
#   Panels Installed: 80,251
#   Installed Capacity: 24.08 MW
#   Local Production: 3.25 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.25 MW
# ------------------------------
# District Nabilatuk:
#   Panels Installed: 53,037
#   Installed Capacity: 15.91 MW
#   Local Production: 2.25 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.25 MW
# ------------------------------
# District Nakapiripirit:
#   Panels Installed: 66,419
#   Installed Capacity: 19.93 MW
#   Local Production: 2.81 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.81 MW
# ------------------------------
# District Otuke:
#   Panels Installed: 78,383
#   Installed Capacity: 23.51 MW
#   Local Production: 3.30 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.30 MW
# ------------------------------
# District Yumbe:
#   Panels Installed: 415,019
#   Installed Capacity: 124.51 MW
#   Local Production: 17.00 MW
#   Capacity Imported: 0.00 MW
#   Demand: 17.00 MW
# ------------------------------
# District Zombo:
#   Panels Installed: 166,041
#   Installed Capacity: 49.81 MW
#   Local Production: 6.71 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.71 MW
# ------------------------------
# District Karenga:
#   Panels Installed: 39,833
#   Installed Capacity: 11.95 MW
#   Local Production: 1.60 MW
#   Capacity Imported: 0.00 MW
#   Demand: 1.60 MW
# ------------------------------
# District Terego:
#   Panels Installed: 133,811
#   Installed Capacity: 40.14 MW
#   Local Production: 5.52 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.52 MW
# ------------------------------
# District Budaka:
#   Panels Installed: 150,697
#   Installed Capacity: 45.21 MW
#   Local Production: 6.11 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.11 MW
# ------------------------------
# District Bududa:
#   Panels Installed: 206,895
#   Installed Capacity: 62.07 MW
#   Local Production: 6.74 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.74 MW
# ------------------------------
# District Bukedea:
#   Panels Installed: 154,124
#   Installed Capacity: 46.24 MW
#   Local Production: 6.40 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.40 MW
# ------------------------------
# District Bukwo:
#   Panels Installed: 73,620
#   Installed Capacity: 22.09 MW
#   Local Production: 3.01 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.01 MW
# ------------------------------
# District Bulambuli:
#   Panels Installed: 147,032
#   Installed Capacity: 44.11 MW
#   Local Production: 5.80 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.80 MW
# ------------------------------
# District Butaleja:
#   Panels Installed: 176,486
#   Installed Capacity: 52.95 MW
#   Local Production: 7.29 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.29 MW
# ------------------------------
# District Butebo:
#   Panels Installed: 67,152
#   Installed Capacity: 20.15 MW
#   Local Production: 2.76 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.76 MW
# ------------------------------
# District Buyende:
#   Panels Installed: 239,964
#   Installed Capacity: 71.99 MW
#   Local Production: 10.27 MW
#   Capacity Imported: 0.00 MW
#   Demand: 10.27 MW
# ------------------------------
# District Kaberamaido:
#   Panels Installed: 75,649
#   Installed Capacity: 22.69 MW
#   Local Production: 3.26 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.26 MW
# ------------------------------
# District Kaliro:
#   Panels Installed: 165,401
#   Installed Capacity: 49.62 MW
#   Local Production: 6.97 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.97 MW
# ------------------------------
# District Kamuli:
#   Panels Installed: 321,404
#   Installed Capacity: 96.42 MW
#   Local Production: 13.07 MW
#   Capacity Imported: 0.00 MW
#   Demand: 13.07 MW
# ------------------------------
# District Kapchorwa:
#   Panels Installed: 75,057
#   Installed Capacity: 22.52 MW
#   Local Production: 2.94 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.94 MW
# ------------------------------
# District Kapelebyong:
#   Panels Installed: 58,078
#   Installed Capacity: 17.42 MW
#   Local Production: 2.47 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.47 MW
# ------------------------------
# District Kibuku:
#   Panels Installed: 146,586
#   Installed Capacity: 43.98 MW
#   Local Production: 6.10 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.10 MW
# ------------------------------
# District Kumi:
#   Panels Installed: 156,997
#   Installed Capacity: 47.10 MW
#   Local Production: 6.79 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.79 MW
# ------------------------------
# District Kween:
#   Panels Installed: 61,584
#   Installed Capacity: 18.48 MW
#   Local Production: 2.59 MW
#   Capacity Imported: 0.00 MW
#   Demand: 2.59 MW
# ------------------------------
# District Mbale:
#   Panels Installed: 167,363
#   Installed Capacity: 50.21 MW
#   Local Production: 6.38 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.38 MW
# ------------------------------
# District Namayingo:
#   Panels Installed: 126,994
#   Installed Capacity: 38.10 MW
#   Local Production: 5.43 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.43 MW
# ------------------------------
# District Namisindwa:
#   Panels Installed: 145,979
#   Installed Capacity: 43.79 MW
#   Local Production: 5.44 MW
#   Capacity Imported: 0.00 MW
#   Demand: 5.44 MW
# ------------------------------
# District Namutumba:
#   Panels Installed: 176,481
#   Installed Capacity: 52.94 MW
#   Local Production: 7.38 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.38 MW
# ------------------------------
# District Ngora:
#   Panels Installed: 89,697
#   Installed Capacity: 26.91 MW
#   Local Production: 3.91 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.91 MW
# ------------------------------
# District Pallisa:
#   Panels Installed: 205,755
#   Installed Capacity: 61.73 MW
#   Local Production: 8.76 MW
#   Capacity Imported: 0.00 MW
#   Demand: 8.76 MW
# ------------------------------
# District Serere:
#   Panels Installed: 203,069
#   Installed Capacity: 60.92 MW
#   Local Production: 8.81 MW
#   Capacity Imported: 0.00 MW
#   Demand: 8.81 MW
# ------------------------------
# District Sironko:
#   Panels Installed: 176,556
#   Installed Capacity: 52.97 MW
#   Local Production: 6.37 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.37 MW
# ------------------------------
# District Manafwa:
#   Panels Installed: 105,003
#   Installed Capacity: 31.50 MW
#   Local Production: 4.09 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.09 MW
# ------------------------------
# District Kalaki:
#   Panels Installed: 79,489
#   Installed Capacity: 23.85 MW
#   Local Production: 3.41 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.41 MW
# ------------------------------
# District Mbale City:
#   Panels Installed: 200,109
#   Installed Capacity: 60.03 MW
#   Local Production: 7.65 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.65 MW
# ------------------------------
# District Soroti City:
#   Panels Installed: 39,080
#   Installed Capacity: 11.72 MW
#   Local Production: 1.69 MW
#   Capacity Imported: 0.00 MW
#   Demand: 1.69 MW
# ------------------------------
# District Buvuma:
#   Panels Installed: 81,098
#   Installed Capacity: 24.33 MW
#   Local Production: 3.38 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.38 MW
# ------------------------------
# District Gomba:
#   Panels Installed: 106,103
#   Installed Capacity: 31.83 MW
#   Local Production: 3.95 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.95 MW
# ------------------------------
# District Kassanda:
#   Panels Installed: 193,912
#   Installed Capacity: 58.17 MW
#   Local Production: 7.33 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.33 MW
# ------------------------------
# District Kiboga:
#   Panels Installed: 103,812
#   Installed Capacity: 31.14 MW
#   Local Production: 4.02 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.02 MW
# ------------------------------
# District Mityana:
#   Panels Installed: 220,018
#   Installed Capacity: 66.01 MW
#   Local Production: 8.31 MW
#   Capacity Imported: 0.00 MW
#   Demand: 8.31 MW
# ------------------------------
# District Mubende:
#   Panels Installed: 376,287
#   Installed Capacity: 112.89 MW
#   Local Production: 14.08 MW
#   Capacity Imported: 0.00 MW
#   Demand: 14.08 MW
# ------------------------------
# District Buhweju:
#   Panels Installed: 97,794
#   Installed Capacity: 29.34 MW
#   Local Production: 3.44 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.44 MW
# ------------------------------
# District Buliisa:
#   Panels Installed: 91,537
#   Installed Capacity: 27.46 MW
#   Local Production: 3.76 MW
#   Capacity Imported: 0.00 MW
#   Demand: 3.76 MW
# ------------------------------
# District Bunyangabu:
#   Panels Installed: 131,362
#   Installed Capacity: 39.41 MW
#   Local Production: 4.56 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.56 MW
# ------------------------------
# District Hoima:
#   Panels Installed: 152,179
#   Installed Capacity: 45.65 MW
#   Local Production: 6.09 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.09 MW
# ------------------------------
# District Kamwenge:
#   Panels Installed: 219,259
#   Installed Capacity: 65.78 MW
#   Local Production: 8.16 MW
#   Capacity Imported: 0.00 MW
#   Demand: 8.16 MW
# ------------------------------
# District Kanungu:
#   Panels Installed: 174,332
#   Installed Capacity: 52.30 MW
#   Local Production: 6.35 MW
#   Capacity Imported: 0.00 MW
#   Demand: 6.35 MW
# ------------------------------
# District Kisoro:
#   Panels Installed: 208,006
#   Installed Capacity: 62.40 MW
#   Local Production: 7.29 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.29 MW
# ------------------------------
# District Kyegegwa:
#   Panels Installed: 324,017
#   Installed Capacity: 97.21 MW
#   Local Production: 12.10 MW
#   Capacity Imported: 0.00 MW
#   Demand: 12.10 MW
# ------------------------------
# District Mitooma:
#   Panels Installed: 119,971
#   Installed Capacity: 35.99 MW
#   Local Production: 4.36 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.36 MW
# ------------------------------
# District Ntoroko:
#   Panels Installed: 46,021
#   Installed Capacity: 13.81 MW
#   Local Production: 1.77 MW
#   Capacity Imported: 0.00 MW
#   Demand: 1.77 MW
# ------------------------------
# District Rubanda:
#   Panels Installed: 132,995
#   Installed Capacity: 39.90 MW
#   Local Production: 4.68 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.68 MW
# ------------------------------
# District Rukungiri:
#   Panels Installed: 202,595
#   Installed Capacity: 60.78 MW
#   Local Production: 7.50 MW
#   Capacity Imported: 0.00 MW
#   Demand: 7.50 MW
# ------------------------------
# District Kitagwenda:
#   Panels Installed: 116,571
#   Installed Capacity: 34.97 MW
#   Local Production: 4.34 MW
#   Capacity Imported: 0.00 MW
#   Demand: 4.34 MW
# ------------------------------

# %%
district_results = {
    "District": district_names,  # Names of districts
    "Panels Installed": [round(Z[i].x, 3) for i in range(num_districts)],  # Total panels installed
    "Installed Capacity (MW)": [round(X[i].x, 3) for i in range(num_districts)],  # Installed capacity
    "Local Production (MW)": [round(X[i].x * S[i], 3) for i in range(num_districts)],  # Local production
    "Capacity Imported (MW)": [round(imported_electricity[i].x, 3) for i in range(num_districts)],  # Electricity imported
    "Demand (MW)": [round(ED[i], 3) for i in range(num_districts)],  # Energy demand
    "Local Production / Demand": [round((X[i].x * S[i]) / ED[i], 3) for i in range(num_districts)]  # Ratio
}

results_df_base = pd.DataFrame(district_results)

# results_df[results_df["Installed Capacity (MW)"] < results_df["Local Production (MW)"]]

# %%
results_df_base
# Out:
#                  District  Panels Installed  Installed Capacity (MW)  \
# 0                    Abim              -0.0                    0.000
# 1                Adjumani              -0.0                    0.000
# 2                   Agago              -0.0                    0.000
# 3                   Amuru              -0.0                    0.000
# 4                    Arua              -0.0                    0.000
# 5                    Gulu              -0.0                    0.000
# 6                  Koboko              -0.0                    0.000
# 7                    Kole              -0.0                    0.000
# 8                  Kotido              -0.0                    0.000
# 9                    Lira              -0.0                    0.000
# 10                Maracha              -0.0                    0.000
# 11                 Moroto              -0.0                    0.000
# 12                   Moyo              -0.0                    0.000
# 13                  Napak              -0.0                    0.000
# 14                  Nebbi              -0.0                    0.000
# 15                  Nwoya              -0.0                    0.000
# 16                  Omoro              -0.0                    0.000
# 17                   Oyam              -0.0                    0.000
# 18                  Pader              -0.0                    0.000
# 19                Pakwach              -0.0                    0.000
# 20                 Obongi              -0.0                    0.000
# 21            Madi Okollo              -0.0                    0.000
# 22              Arua City           28173.0                    8.452
# 23              Gulu City              -0.0                    0.000
# 24              Lira City              -0.0                    0.000
# 25                 Amuria              -0.0                    0.000
# 26                 Bugiri              -0.0                    0.000
# 27                Bugweri              -0.0                    0.000
# 28                  Busia          430332.0                  129.100
# 29                 Iganga              -0.0                    0.000
# 30                  Jinja              -0.0                    0.000
# 31                Katakwi              -0.0                    0.000
# 32                  Luuka              -0.0                    0.000
# 33                 Mayuge              -0.0                    0.000
# 34                 Soroti              -0.0                    0.000
# 35                 Tororo          308865.0                   92.659
# 36             Jinja City              -0.0                    0.000
# 37                 Buikwe              -0.0                    0.000
# 38           Bukomansimbi              -0.0                    0.000
# 39              Butambala              -0.0                    0.000
# 40              Kalangala              -0.0                    0.000
# 41                Kalungu              -0.0                    0.000
# 42   Kampala Capital City              -0.0                    0.000
# 43                Kayunga              -0.0                    0.000
# 44             Kyankwanzi              -0.0                    0.000
# 45                Kyotera              -0.0                    0.000
# 46                 Luwero              -0.0                    0.000
# 47                 Lwengo              -0.0                    0.000
# 48              Lyantonde              -0.0                    0.000
# 49                 Masaka              -0.0                    0.000
# 50                  Mpigi              -0.0                    0.000
# 51                 Mukono              -0.0                    0.000
# 52               Nakaseke              -0.0                    0.000
# 53            Nakasongola              -0.0                    0.000
# 54                  Rakai              -0.0                    0.000
# 55             Ssembabule              -0.0                    0.000
# 56                 Wakiso              -0.0                    0.000
# 57            Masaka City              -0.0                    0.000
# 58             Bundibugyo              -0.0                    0.000
# 59               Bushenyi              -0.0                    0.000
# 60                 Ibanda              -0.0                    0.000
# 61               Isingiro              -0.0                    0.000
# 62                 Kabale              -0.0                    0.000
# 63               Kabarole              -0.0                    0.000
# 64                 Kagadi              -0.0                    0.000
# 65               Kakumiro              -0.0                    0.000
# 66                 Kasese              -0.0                    0.000
# 67                Kibaale              -0.0                    0.000
# 68                Kikuube              -0.0                    0.000
# 69               Kiruhura              -0.0                    0.000
# 70            Kiryandongo              -0.0                    0.000
# 71               Kyenjojo              -0.0                    0.000
# 72                Masindi              -0.0                    0.000
# 73                Mbarara              -0.0                    0.000
# 74               Ntungamo              -0.0                    0.000
# 75               Rubirizi              -0.0                    0.000
# 76                 Rukiga              -0.0                    0.000
# 77                 Sheema              -0.0                    0.000
# 78                   Kazo              -0.0                    0.000
# 79               Rwampara              -0.0                    0.000
# 80       Fort Portal City              -0.0                    0.000
# 81             Hoima City              -0.0                    0.000
# 82           Mbarara City              -0.0                    0.000
# 83               Alebtong          148078.0                   44.423
# 84               Amolatar           92867.0                   27.860
# 85                 Amudat           77782.0                   23.335
# 86                   Apac          132232.0                   39.670
# 87                 Dokolo          120507.0                   36.152
# 88                Kaabong           70227.0                   21.068
# 89                 Kitgum          125785.0                   37.735
# 90                 Kwania          121840.0                   36.552
# 91                  Lamwo           80251.0                   24.075
# 92              Nabilatuk           53037.0                   15.911
# 93          Nakapiripirit           66419.0                   19.926
# 94                  Otuke           78383.0                   23.515
# 95                  Yumbe          415019.0                  124.506
# 96                  Zombo          166041.0                   49.812
# 97                Karenga           39833.0                   11.950
# 98                 Terego          133811.0                   40.143
# 99                 Budaka          150697.0                   45.209
# 100                Bududa          206895.0                   62.068
# 101               Bukedea          154124.0                   46.237
# 102                 Bukwo           73620.0                   22.086
# 103             Bulambuli          147032.0                   44.110
# 104              Butaleja          176486.0                   52.946
# 105                Butebo           67152.0                   20.146
# 106               Buyende          239964.0                   71.989
# 107           Kaberamaido           75649.0                   22.695
# 108                Kaliro          165401.0                   49.620
# 109                Kamuli          321404.0                   96.421
# 110             Kapchorwa           75057.0                   22.517
# 111           Kapelebyong           58078.0                   17.423
# 112                Kibuku          146586.0                   43.976
# 113                  Kumi          156997.0                   47.099
# 114                 Kween           61584.0                   18.475
# 115                 Mbale          167363.0                   50.209
# 116             Namayingo          126994.0                   38.098
# 117            Namisindwa          145979.0                   43.794
# 118             Namutumba          176481.0                   52.944
# 119                 Ngora           89697.0                   26.909
# 120               Pallisa          205755.0                   61.726
# 121                Serere          203069.0                   60.921
# 122               Sironko          176556.0                   52.967
# 123               Manafwa          105003.0                   31.501
# 124                Kalaki           79489.0                   23.847
# 125            Mbale City          200109.0                   60.033
# 126           Soroti City           39080.0                   11.724
# 127                Buvuma           81098.0                   24.329
# 128                 Gomba          106103.0                   31.831
# 129              Kassanda          193912.0                   58.174
# 130                Kiboga          103812.0                   31.144
# 131               Mityana          220018.0                   66.005
# 132               Mubende          376287.0                  112.886
# 133               Buhweju           97794.0                   29.338
# 134               Buliisa           91537.0                   27.461
# 135            Bunyangabu          131362.0                   39.409
# 136                 Hoima          152179.0                   45.654
# 137              Kamwenge          219259.0                   65.778
# 138               Kanungu          174332.0                   52.300
# 139                Kisoro          208006.0                   62.402
# 140              Kyegegwa          324017.0                   97.205
# 141               Mitooma          119971.0                   35.991
# 142               Ntoroko           46021.0                   13.806
# 143               Rubanda          132995.0                   39.898
# 144             Rukungiri          202595.0                   60.778
# 145            Kitagwenda          116571.0                   34.971
#
#      Local Production (MW)  Capacity Imported (MW)  Demand (MW)  \
# 0                    0.000                   0.200        4.009
# 1                    0.000                   0.263        5.263
# 2                    0.000                   0.288        5.757
# 3                    0.000                   0.255        5.099
# 4                    0.000                   0.185        3.693
# 5                    0.000                   0.139        2.785
# 6                    0.000                   0.315        6.305
# 7                    0.000                   0.339        6.772
# 8                    0.000                   0.241        4.818
# 9                    0.000                   0.278        5.564
# 10                   0.000                   0.241        4.814
# 11                   0.000                   0.138        2.770
# 12                   0.000                   0.128        2.553
# 13                   0.000                   0.182        3.645
# 14                   0.000                   0.336        6.717
# 15                   0.000                   0.345        6.893
# 16                   0.000                   0.237        4.746
# 17                   0.000                   0.539       10.781
# 18                   0.000                   0.227        4.533
# 19                   0.000                   0.240        4.803
# 20                   0.000                   0.057        1.147
# 21                   0.000                   0.194        3.877
# 22                   1.169                   0.000        8.542
# 23                   0.000                   0.247        4.945
# 24                   0.000                   0.288        5.752
# 25                   0.000                   0.272        5.450
# 26                   0.000                   0.588       11.764
# 27                   0.000                   0.225        4.509
# 28                  18.271                   0.000        9.139
# 29                   0.000                   0.479        9.579
# 30                   0.000                   0.280        5.590
# 31                   0.000                   0.230        4.599
# 32                   0.000                   0.309        6.176
# 33                   0.000                   0.675       13.492
# 34                   0.000                   0.355        7.101
# 35                  12.950                   0.000       14.029
# 36                   0.000                   0.308        6.160
# 37                   0.000                   0.548       10.961
# 38                   0.000                   0.174        3.474
# 39                   0.000                   0.122        2.432
# 40                   0.000                   0.082        1.634
# 41                   0.000                   0.207        4.149
# 42                   0.000                   1.937       38.741
# 43                   0.000                   0.468        9.367
# 44                   0.000                   0.355        7.103
# 45                   0.000                   0.297        5.945
# 46                   0.000                   0.612       12.240
# 47                   0.000                   0.326        6.518
# 48                   0.000                   0.131        2.623
# 49                   0.000                   0.140        2.798
# 50                   0.000                   0.335        6.696
# 51                   0.000                   0.831       16.613
# 52                   0.000                   0.280        5.590
# 53                   0.000                   0.256        5.119
# 54                   0.000                   0.372        7.432
# 55                   0.000                   0.350        7.003
# 56                   0.000                   3.859       77.181
# 57                   0.000                   0.260        5.202
# 58                   0.000                   0.313        6.250
# 59                   0.000                   0.279        5.575
# 60                   0.000                   0.319        6.380
# 61                   0.000                   0.722       14.433
# 62                   0.000                   0.282        5.634
# 63                   0.000                   0.258        5.163
# 64                   0.000                   0.521       10.411
# 65                   0.000                   0.660       13.200
# 66                   0.000                   0.925       18.507
# 67                   0.000                   0.257        5.149
# 68                   0.000                   0.454        9.088
# 69                   0.000                   0.225        4.502
# 70                   0.000                   0.372        7.439
# 71                   0.000                   0.641       12.816
# 72                   0.000                   0.402        8.046
# 73                   0.000                   0.197        3.932
# 74                   0.000                   0.624       12.483
# 75                   0.000                   0.166        3.323
# 76                   0.000                   0.118        2.351
# 77                   0.000                   0.248        4.963
# 78                   0.000                   0.264        5.272
# 79                   0.000                   0.168        3.358
# 80                   0.000                   0.134        2.678
# 81                   0.000                   0.148        2.967
# 82                   0.000                   0.257        5.147
# 83                   6.281                   0.000        6.281
# 84                   3.991                   0.000        3.991
# 85                   3.331                   0.000        3.331
# 86                   5.474                   0.000        5.474
# 87                   5.108                   0.000        5.108
# 88                   2.948                   0.000        2.948
# 89                   5.108                   0.000        5.108
# 90                   5.145                   0.000        5.145
# 91                   3.248                   0.000        3.248
# 92                   2.248                   0.000        2.248
# 93                   2.809                   0.000        2.809
# 94                   3.303                   0.000        3.303
# 95                  16.996                   0.000       16.996
# 96                   6.713                   0.000        6.713
# 97                   1.603                   0.000        1.603
# 98                   5.516                   0.000        5.516
# 99                   6.110                   0.000        6.110
# 100                  6.737                   0.000        6.737
# 101                  6.399                   0.000        6.399
# 102                  3.009                   0.000        3.009
# 103                  5.801                   0.000        5.801
# 104                  7.285                   0.000        7.285
# 105                  2.757                   0.000        2.757
# 106                 10.272                   0.000       10.272
# 107                  3.261                   0.000        3.261
# 108                  6.972                   0.000        6.972
# 109                 13.073                   0.000       13.073
# 110                  2.937                   0.000        2.937
# 111                  2.467                   0.000        2.467
# 112                  6.101                   0.000        6.101
# 113                  6.788                   0.000        6.788
# 114                  2.588                   0.000        2.588
# 115                  6.382                   0.000        6.382
# 116                  5.426                   0.000        5.426
# 117                  5.437                   0.000        5.437
# 118                  7.378                   0.000        7.378
# 119                  3.912                   0.000        3.912
# 120                  8.761                   0.000        8.761
# 121                  8.812                   0.000        8.812
# 122                  6.371                   0.000        6.371
# 123                  4.086                   0.000        4.086
# 124                  3.408                   0.000        3.408
# 125                  7.647                   0.000        7.647
# 126                  1.693                   0.000        1.693
# 127                  3.382                   0.000        3.382
# 128                  3.954                   0.000        3.954
# 129                  7.327                   0.000        7.327
# 130                  4.020                   0.000        4.020
# 131                  8.307                   0.000        8.307
# 132                 14.075                   0.000       14.075
# 133                  3.441                   0.000        3.441
# 134                  3.757                   0.000        3.757
# 135                  4.562                   0.000        4.562
# 136                  6.092                   0.000        6.092
# 137                  8.158                   0.000        8.158
# 138                  6.347                   0.000        6.347
# 139                  7.285                   0.000        7.285
# 140                 12.104                   0.000       12.104
# 141                  4.362                   0.000        4.362
# 142                  1.770                   0.000        1.770
# 143                  4.680                   0.000        4.680
# 144                  7.500                   0.000        7.500
# 145                  4.338                   0.000        4.338
#
#      Local Production / Demand
# 0                        0.000
# 1                        0.000
# 2                        0.000
# 3                        0.000
# 4                        0.000
# 5                        0.000
# 6                        0.000
# 7                        0.000
# 8                        0.000
# 9                        0.000
# 10                       0.000
# 11                       0.000
# 12                       0.000
# 13                       0.000
# 14                       0.000
# 15                       0.000
# 16                       0.000
# 17                       0.000
# 18                       0.000
# 19                       0.000
# 20                       0.000
# 21                       0.000
# 22                       0.137
# 23                       0.000
# 24                       0.000
# 25                       0.000
# 26                       0.000
# 27                       0.000
# 28                       1.999
# 29                       0.000
# 30                       0.000
# 31                       0.000
# 32                       0.000
# 33                       0.000
# 34                       0.000
# 35                       0.923
# 36                       0.000
# 37                       0.000
# 38                       0.000
# 39                       0.000
# 40                       0.000
# 41                       0.000
# 42                       0.000
# 43                       0.000
# 44                       0.000
# 45                       0.000
# 46                       0.000
# 47                       0.000
# 48                       0.000
# 49                       0.000
# 50                       0.000
# 51                       0.000
# 52                       0.000
# 53                       0.000
# 54                       0.000
# 55                       0.000
# 56                       0.000
# 57                       0.000
# 58                       0.000
# 59                       0.000
# 60                       0.000
# 61                       0.000
# 62                       0.000
# 63                       0.000
# 64                       0.000
# 65                       0.000
# 66                       0.000
# 67                       0.000
# 68                       0.000
# 69                       0.000
# 70                       0.000
# 71                       0.000
# 72                       0.000
# 73                       0.000
# 74                       0.000
# 75                       0.000
# 76                       0.000
# 77                       0.000
# 78                       0.000
# 79                       0.000
# 80                       0.000
# 81                       0.000
# 82                       0.000
# 83                       1.000
# 84                       1.000
# 85                       1.000
# 86                       1.000
# 87                       1.000
# 88                       1.000
# 89                       1.000
# 90                       1.000
# 91                       1.000
# 92                       1.000
# 93                       1.000
# 94                       1.000
# 95                       1.000
# 96                       1.000
# 97                       1.000
# 98                       1.000
# 99                       1.000
# 100                      1.000
# 101                      1.000
# 102                      1.000
# 103                      1.000
# 104                      1.000
# 105                      1.000
# 106                      1.000
# 107                      1.000
# 108                      1.000
# 109                      1.000
# 110                      1.000
# 111                      1.000
# 112                      1.000
# 113                      1.000
# 114                      1.000
# 115                      1.000
# 116                      1.000
# 117                      1.000
# 118                      1.000
# 119                      1.000
# 120                      1.000
# 121                      1.000
# 122                      1.000
# 123                      1.000
# 124                      1.000
# 125                      1.000
# 126                      1.000
# 127                      1.000
# 128                      1.000
# 129                      1.000
# 130                      1.000
# 131                      1.000
# 132                      1.000
# 133                      1.000
# 134                      1.000
# 135                      1.000
# 136                      1.000
# 137                      1.000
# 138                      1.000
# 139                      1.000
# 140                      1.000
# 141                      1.000
# 142                      1.000
# 143                      1.000
# 144                      1.000
# 145                      1.000

# %%
#results_df.to_csv("final_allocation.csv")

# %%
#Sensitivity function
def test_optimization(
    df, 
    baseline_results,
    budget=None,
    installation_cost=None,
    transportation_cost=None,
    demand_change=None
):
    """
    Test the optimization model under different parameter levels.

    Parameters:
    - df: DataFrame containing district data.
    - baseline_results: Dictionary with baseline optimization results.
    - budget: Modified budget ($).
    - installation_cost: Modified installation cost per MW ($).
    - transportation_cost: Modified transportation cost per panel per km ($).
    - demand_change: Percentual change in demand (e.g., 0.1 for +10%).

    Returns:
    - results_df: DataFrame with optimization results.
    - differences_df: DataFrame with differences from the baseline.
    """

    # Adjust demand if demand_change is provided
    S = df['MEANSOLAR'] * 30 / 1e3  # Solar efficiency remains constant
    X_coords = df['X'].values
    Y_coords = df['Y'].values
    district_ids = df['ID'].tolist()
    district_names = df['Name'].tolist()
    num_districts = len(df)
    supplier_indices = df[df['Suppliers'] == 1].index.tolist()
    num_suppliers = len(supplier_indices)
    energy_consumption_per_person = (96.3 / 4.5)  # kWh/month divided by average people per household
    transmission_loss_per_km = 0.0377 / 1000  # Loss per km (fraction)
    max_transmission_capacity = 500  # MW/month
    M = 1e6  # Big M for binary constraints
    EP = 0.3 / 1e3  # Panel capacity (MWp)
    S = df['MEANSOLAR'] * 30 / 1e3  # Convert to MW per MWp per month
    P = df['PercentagePark'].values / 100
    D = np.zeros((num_districts, num_districts))

    # Modified parameters
    B = budget if budget is not None else 4e9
    C_install = installation_cost if installation_cost is not None else 1.1e6
    C_T = transportation_cost if transportation_cost is not None else 0.1
    ED = (df['2021_Total_Population']* energy_consumption_per_person / 1e6)* (1 + (demand_change if demand_change else 0))  # MW/month

    
    def haversine(lon1, lat1, lon2, lat2):
        # Calculate distance between two points on Earth
        lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
        c = 2 * np.arcsin(np.sqrt(a))
        km = 6371 * c  # Radius of Earth in km
        return km

    for i in range(num_districts):
        for j in range(num_districts):
            if i != j:
                D[i, j] = haversine(X_coords[i], Y_coords[j], X_coords[j], Y_coords[i])

    # Initialize model
    model = gp.Model("Solar_Panels_Optimization")
    model.Params.LogToConsole = 0

    # Decision Variables
    X = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="InstalledCapacity")
    Z = model.addVars(num_districts, vtype=GRB.INTEGER, lb=0, name="TotalPanels")
    T = model.addVars(num_suppliers, num_districts, vtype=GRB.INTEGER, lb=0, name="TransportedPanels")
    y = model.addVars(num_districts, vtype=GRB.BINARY, name="InstallDecision")
    A = model.addVars(num_districts, num_districts, vtype=GRB.CONTINUOUS, lb=0, name="TransferredEnergy")
    exportable_energy = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="ExportableEnergy")
    surplus = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=-GRB.INFINITY, name="Surplus")
    delta = model.addVars(num_districts, vtype=GRB.BINARY, name="ExportDecision")
    imported_electricity = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="ImportedElectricity")
    E = model.addVars(num_districts, vtype=GRB.CONTINUOUS, lb=0, name="EnergyProduced")

    # Objective: Minimize installation and transportation costs
    model.setObjective(
        gp.quicksum(X[i] * C_install for i in range(num_districts)) +
        gp.quicksum(T[k, i] * C_T * D[supplier_indices[k], i] for k in range(num_suppliers) for i in range(num_districts)),
        GRB.MINIMIZE
    )

    # Define demand satisfaction ratio based on GridConnections
    demand_satisfaction_ratio = [
        0.05 if df.loc[i, 'GridAll'] > 0 else 1
        for i in range(num_districts)
    ]

    # Constraints
    for i in range(num_districts):
        # Panels balance
        model.addConstr(gp.quicksum(T[k, i] for k in range(num_suppliers)) == Z[i], f"PanelsBalance_District_{i}")
        
        # Installed capacity
        model.addConstr(X[i] == Z[i] * EP, f"InstalledCapacity_District_{i}")

        # Demand satisfaction with adjusted ratio
        local_production = X[i] * S[i]
        model.addConstr(
            local_production + imported_electricity[i] >= ED[i] * demand_satisfaction_ratio[i],
            f"DemandSatisfaction_District_{i}"
        )
        
        # Surplus and exportable energy
        model.addConstr(surplus[i] == local_production - ED[i] * demand_satisfaction_ratio[i], f"Surplus_District_{i}")
        model.addConstr(exportable_energy[i] == surplus[i] * delta[i], f"ExportableEnergy_District_{i}")
        
        # Import electricity
        model.addConstr(
            imported_electricity[i] == gp.quicksum(A[j, i] * np.exp(-transmission_loss_per_km * D[j, i]) for j in range(num_districts) if j != i),
            f"ImportedElectricity_District_{i}"
        )
        
        # Binary installation constraints
        model.addConstr(X[i] <= M * y[i], f"BinaryInstallationConstraint_District_{i}")
        
        # Grid constraint for delta[i]
        if df.loc[i, 'GridAll'] == 0:
            model.addConstr(delta[i] == 0, f"GridConstraint_District_{i}")
        
        # Surplus and Export Decision
        model.addConstr(
            surplus[i] >= 0.0001 - M * (1 - delta[i]),
            f"PositiveSurplusForExport_District_{i}"
        )

        # Energy production constraint for districts without grid (100% of demand)
        if df.loc[i, 'GridAll'] == 0:
            model.addConstr(E[i] >= ED[i], f"MinProductionNoGrid_District_{i}")
        
        # Link energy produced (E[i]) to local production
        model.addConstr(E[i] == X[i] * S[i], f"EnergyProduced_District_{i}")
        
        # Maximum production limit (200% of demand)
        model.addConstr(E[i] <= 2 * ED[i], f"MaxProductionLimit_District_{i}")

    for j in range(num_districts):
        # Export Limit by Surplus
        model.addConstr(
            gp.quicksum(A[j, i] for i in range(num_districts) if i != j) <= exportable_energy[j],
            f"ExportLimit_District_{j}"
        )
        # Transmission Capacity Limit
        model.addConstr(
            gp.quicksum(A[j, i] for i in range(num_districts) if i != j) <= max_transmission_capacity * delta[j],
            f"TransmissionCapacity_District_{j}"
        )
        # No Self-Transfer
        model.addConstr(A[j, j] == 0, f"NoSelfTransfer_District_{j}")

    # Energy balance
    model.addConstr(
        gp.quicksum(imported_electricity[i] for i in range(num_districts)) == 
        gp.quicksum(A[j, i] * np.exp(-transmission_loss_per_km * D[j, i]) for j in range(num_districts) for i in range(num_districts) if i != j),
        "EnergyBalance"
    )

    # Budget constraint
    total_cost = gp.quicksum(X[i] * C_install for i in range(num_districts)) + \
                gp.quicksum(T[k, i] * C_T * D[supplier_indices[k], i] for k in range(num_suppliers) for i in range(num_districts))
    model.addConstr(total_cost <= B, "BudgetConstraint")

    # Optimize and display results
    model.optimize()
        
        
        # Collect results if the solution is feasible
    if model.status == GRB.OPTIMAL:
       results = {
             "District": df['Name'].tolist(),
           "Panels Installed": [round(model.getVarByName(f"TotalPanels[{i}]").X, 3) for i in range(num_districts)],
            "Installed Capacity (MW)": [round(model.getVarByName(f"InstalledCapacity[{i}]").X, 3) for i in range(num_districts)],
            "Total Cost": round(model.objVal, 3)
       }
           
           # Calculate differences from baseline
       differences = {
           "District": results["District"],
               "Panels Installed Diff": [
                   results["Panels Installed"][i] - baseline_results["Panels Installed"][i] 
                   for i in range(num_districts)
               ],
               "Installed Capacity Diff (MW)": [
                   results["Installed Capacity (MW)"][i] - baseline_results["Installed Capacity (MW)"][i]
                   for i in range(num_districts)
               ]
           }
            
       results_df = pd.DataFrame(results)
       differences_df = pd.DataFrame(differences)
       # Filter rows where there is at least one positive value
       differences_df = differences_df[(differences_df["Panels Installed Diff"] > 0) | (differences_df["Installed Capacity Diff (MW)"] > 0)]

            
       return results_df, differences_df
    else:
        print("No feasible solution found.")
        return None, None

# %%
  
results_df,differences = test_optimization(
    df=df,
    baseline_results=results_df_base,
    demand_change=0.1
)

# Display filtered results
print(differences)
# Out:
#           District  Panels Installed Diff  Installed Capacity Diff (MW)
# 22       Arua City                 2818.0                         0.845
# 28           Busia                43033.0                        12.909
# 35          Tororo                30887.0                         9.267
# 83        Alebtong                14808.0                         4.443
# 84        Amolatar                 9286.0                         2.786
# 85          Amudat                 7778.0                         2.333
# 86            Apac                13223.0                         3.966
# 87          Dokolo                12050.0                         3.615
# 88         Kaabong                 7022.0                         2.107
# 89          Kitgum                12578.0                         3.774
# 90          Kwania                12183.0                         3.655
# 91           Lamwo                 8025.0                         2.408
# 92       Nabilatuk                 5304.0                         1.591
# 93   Nakapiripirit                 6641.0                         1.992
# 94           Otuke                 7839.0                         2.352
# 95           Yumbe                41502.0                        12.450
# 96           Zombo                16604.0                         4.981
# 97         Karenga                 3984.0                         1.195
# 98          Terego                13381.0                         4.015
# 99          Budaka                15070.0                         4.521
# 100         Bududa                20689.0                         6.207
# 101        Bukedea                15412.0                         4.624
# 102          Bukwo                 7362.0                         2.209
# 103      Bulambuli                14703.0                         4.410
# 104       Butaleja                17648.0                         5.294
# 105         Butebo                 6715.0                         2.014
# 106        Buyende                23997.0                         7.199
# 107    Kaberamaido                 7565.0                         2.269
# 108         Kaliro                16541.0                         4.963
# 109         Kamuli                32140.0                         9.642
# 110      Kapchorwa                 7506.0                         2.252
# 111    Kapelebyong                 5808.0                         1.743
# 112         Kibuku                14659.0                         4.397
# 113           Kumi                15700.0                         4.710
# 114          Kween                 6158.0                         1.848
# 115          Mbale                16736.0                         5.021
# 116      Namayingo                12699.0                         3.810
# 117     Namisindwa                14598.0                         4.379
# 118      Namutumba                17648.0                         5.295
# 119          Ngora                 8970.0                         2.691
# 120        Pallisa                20575.0                         6.173
# 121         Serere                20307.0                         6.092
# 122        Sironko                17656.0                         5.297
# 123        Manafwa                10500.0                         3.150
# 124         Kalaki                 7949.0                         2.384
# 125     Mbale City                20011.0                         6.003
# 126    Soroti City                 3908.0                         1.172
# 127         Buvuma                 8110.0                         2.433
# 128          Gomba                10610.0                         3.183
# 129       Kassanda                19392.0                         5.817
# 130         Kiboga                10381.0                         3.114
# 131        Mityana                22002.0                         6.601
# 132        Mubende                37628.0                        11.288
# 133        Buhweju                 9779.0                         2.934
# 134        Buliisa                 9154.0                         2.746
# 135     Bunyangabu                13136.0                         3.940
# 136          Hoima                15218.0                         4.565
# 137       Kamwenge                21926.0                         6.577
# 138        Kanungu                17433.0                         5.229
# 139         Kisoro                20800.0                         6.240
# 140       Kyegegwa                32402.0                         9.721
# 141        Mitooma                11997.0                         3.599
# 142        Ntoroko                 4602.0                         1.381
# 143        Rubanda                13299.0                         3.990
# 144      Rukungiri                20259.0                         6.078
# 145     Kitagwenda                11657.0                         3.497
